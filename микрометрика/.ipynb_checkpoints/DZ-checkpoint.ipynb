# %%
import pandas as pd
import numpy as np
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
spss = pd.read_spss("./r25i_os_31.sav")

# %%
df = pd.DataFrame(spss)

# %%
df
# Out:
#             idind     uredid_i            uid_i          uid_h  \
# 0         3.00000 146901.00000    1001201.00000    10012.00000
# 1         7.00000 147101.00000    1000301.00000    10003.00000
# 2         9.00000 146801.00000    1000401.00000    10004.00000
# 3        36.00000 145501.00000    1002401.00000    10024.00000
# 4        37.00000 145502.00000    1002402.00000    10024.00000
# ...           ...          ...              ...            ...
# 12549 54154.00000 668204.00000 1402452204.00000 14024522.00000
# 12550 54155.00000 668205.00000 1402452205.00000 14024522.00000
# 12551 54156.00000 668206.00000 1402452206.00000 14024522.00000
# 12552 54498.00000 489602.00000  138175102.00000  1381751.00000
# 12553 58397.00000 643606.00000  136098906.00000  1360989.00000
#
#                 tid_i         tid_h         sid_i       sid_h         rid_i  \
# 0       1001201.00000   10012.00000 1001201.00000 10012.00000 1001201.00000
# 1       1000301.00000   10003.00000 1000301.00000 10003.00000 1000301.00000
# 2       1000401.00000   10004.00000 1000401.00000 10004.00000 1000401.00000
# 3       1002401.00000   10024.00000 1002401.00000 10024.00000 1002401.00000
# 4       1002402.00000   10024.00000 1002402.00000 10024.00000 1002402.00000
# ...               ...           ...           ...         ...           ...
# 12549             nan           nan           nan         nan           nan
# 12550             nan           nan           nan         nan           nan
# 12551             nan           nan           nan         nan           nan
# 12552             nan           nan           nan         nan           nan
# 12553 136098906.00000 1360989.00000           nan         nan           nan
#
#             rid_h  ...  um101  um102  um103  um104  um105  um106  um107  \
# 0     10012.00000  ...    NaN    nan    NaN    NaN    NaN    NaN    NaN
# 1     10003.00000  ...    NaN    nan    NaN    NaN    NaN    NaN    NaN
# 2     10004.00000  ...    NaN    nan    NaN    NaN    NaN    NaN    NaN
# 3     10024.00000  ...    NaN    nan    NaN    NaN    NaN    NaN    NaN
# 4     10024.00000  ...    NaN    nan    NaN    NaN    NaN    NaN    NaN
# ...           ...  ...    ...    ...    ...    ...    ...    ...    ...
# 12549         nan  ...    Нет    nan    NaN    NaN    NaN    NaN    NaN
# 12550         nan  ...    Нет    nan    NaN    NaN    NaN    NaN    NaN
# 12551         nan  ...    Нет    nan    NaN    NaN    NaN    NaN    NaN
# 12552         nan  ...    NaN    nan    NaN    NaN    NaN    NaN    NaN
# 12553         nan  ...    Нет    nan    NaN    NaN    NaN    NaN    NaN
#
#        um108  um109  um111
# 0        NaN    NaN    NaN
# 1        NaN    NaN    NaN
# 2        NaN    NaN    NaN
# 3        NaN    NaN    NaN
# 4        NaN    NaN    NaN
# ...      ...    ...    ...
# 12549    NaN    Нет    NaN
# 12550    NaN    Нет    NaN
# 12551    NaN    Нет    NaN
# 12552    NaN    NaN    NaN
# 12553    NaN    Нет    NaN
#
# [12554 rows x 862 columns]

# %%
df.describe()
edu_mar = df[['u_marst', 'u_educ']].dropna()

# %%
edu_mar
# Out:
#                                      u_marst  \
# 0                             Bдовец (вдова)
# 1                Никогда в браке не состояли
# 2        Состоите в зарегистрированном браке
# 3        Состоите в зарегистрированном браке
# 4        Состоите в зарегистрированном браке
# ...                                      ...
# 12544            Никогда в браке не состояли
# 12545            Никогда в браке не состояли
# 12546        Разведены и в браке не состоите
# 12548  Живете вместе, но не зарегистрированы
# 12552    Состоите в зарегистрированном браке
#
#                                                   u_educ
# 0      10 и более классов школы и какое-либо професс....
# 1                                        7 классов школы
# 2                    1-2 года в высшем учебном заведении
# 3                                        8 классов школы
# 4      среднее образование - есть аттестат о ср. обра...
# ...                                                  ...
# 12544                   есть диплом о высшем образовании
# 12545           3 и более лет в высшем учебном заведении
# 12546                   есть диплом о высшем образовании
# 12548    10 и более классов школы и техникум без диплома
# 12552                   есть диплом о высшем образовании
#
# [10622 rows x 2 columns]

# %%
def filter_rows(df, column_name, value):
    return df[df[column_name] != value]
def show_categories(df, column_name):
    d = {x : len(df[df[column_name] == x]) for x in list(df[column_name].dtype.categories)}
    d.update({'Всего' : len(df)})
    return d
def replace_categories(df, column_name, replacesments: dict):
    for k,v in replacesments.items():
        df[df[column_name] == k] = v
    return df

# %%
df_formatted = filter_rows(edu_mar, 'u_marst', 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ')
df_formatted = filter_rows(df_formatted, 'u_marst', 'НЕТ ОТВЕТА')
df_formatted = filter_rows(df_formatted, 'u_marst', 'ОТКАЗ ОТ ОТВЕТА')

# %%
print(len(df[df['u_marst'] == 'Состоите в зарегистрированном браке']))
df_formatted['u_marst'].dtype.categories[0]
# Out:
#   File "<ipython-input-34-eaaf80afb2b0>", line 3
#     pd.get_dummies(data=df_formatted['u_marst'])??
#                                                 ^
# SyntaxError: invalid syntax

# %%
show_categories(df_formatted, 'u_marst')
# Out:
# {'Bдовец (вдова)': 1457,
#  'Живете вместе, но не зарегистрированы': 1018,
#  'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ': 0,
#  'НЕТ ОТВЕТА': 0,
#  'Никогда в браке не состояли': 2005,
#  'ОТКАЗ ОТ ОТВЕТА': 0,
#  'ОФИЦИАЛЬНО ЗАРЕГИСТРИРОВАНЫ, НО ВМЕСТЕ НЕ ПРОЖИВАЮТ': 44,
#  'Разведены и в браке не состоите': 868,
#  'Состоите в зарегистрированном браке': 5218,
#  'Всего': 10610}

# %%
replace_categories(df_formatted, 'u_marst', {'Состоите в зарегистрированном браке' : 1})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-01bdbd0be43c> in <module>
# ----> 1 replace_categories(df_formatted, 'u_marst', {'Состоите в зарегистрированном браке' : 1})
#
# <ipython-input-27-ba432b46c644> in replace_categories(df, column_name, replacesments)
#       7 def replace_categories(df, column_name, replacesments: dict):
#       8     for k,v in replacesments.items():
# ----> 9         df[df[column_name] == k] = v
#      10     return df
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3462             self._setitem_frame(key, value)
#    3463         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3464             self._setitem_array(key, value)
#    3465         else:
#    3466             # set column
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3481             indexer = key.nonzero()[0]
#    3482             self._check_setitem_copy()
# -> 3483             self.loc._setitem_with_indexer(indexer, value)
#    3484         else:
#    3485             if isinstance(value, DataFrame):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     541                 # scalar
#     542                 for item in labels:
# --> 543                     setter(item, value)
#     544
#     545         else:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in setter(item, v)
#     474                     s._consolidate_inplace()
#     475                     s = s.copy()
# --> 476                     s._data = s._data.setitem(indexer=pi, value=v)
#     477                     s._maybe_update_cacher(clear=True)
#     478
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/managers.py in setitem(self, **kwargs)
#     558
#     559     def setitem(self, **kwargs):
# --> 560         return self.apply("setitem", **kwargs)
#     561
#     562     def putmask(self, **kwargs):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value)
#    1834
#    1835         check_setitem_lengths(indexer, value, self.values)
# -> 1836         self.values[indexer] = value
#    1837         return self
#    1838
#
# /usr/local/lib/python3.7/site-packages/pandas/core/arrays/categorical.py in __setitem__(self, key, value)
#    2188         if len(to_add) and not isna(to_add).all():
#    2189             raise ValueError(
# -> 2190                 "Cannot setitem on a Categorical with a new "
#    2191                 "category, set the categories first"
#    2192             )
#
# ValueError: Cannot setitem on a Categorical with a new category, set the categories first
